# %% [markdown]
# # Day 1 — Core Mechanics
#
# **Source (strict):** Kaggle Pandas micro-course: https://www.kaggle.com/learn/pandas
#
# **Dataset:** winemag-data-130k-v2.csv
#
# Attempt each question in its own code cell below. Add a short markdown note with your answer/finding after each.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# df = pd.read_csv('your_dataset.csv')  # <-- point this at your downloaded dataset

# %% [markdown]
# ### Q1. Load the wine reviews CSV. Print shape, dtypes, and first 5 rows.

# %%
wine_reviews = pd.read_csv(r"C:\Users\shata\Downloads\winemag-data-130k-v2.csv.zip", index_col=0)
wine_reviews.shape
wine_reviews.dtypes
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# ### Q2. Select the `country` and `points` columns only, first 15 rows.

# %%
wine_reviews.loc[:14, ['country', 'points']]
# Out:
#      country  points
# 0      Italy      87
# 1   Portugal      87
# 2         US      87
# 3         US      87
# 4         US      87
# 5      Spain      87
# 6      Italy      87
# 7     France      87
# 8    Germany      87
# 9     France      87
# 10        US      87
# 11    France      87
# 12        US      87
# 13     Italy      87
# 14        US      87

# %% [markdown]
# ### Q3. Select all rows where `points >= 95` AND `price <= 20`.

# %%
wine_reviews.loc[(wine_reviews.points>=95) & (wine_reviews.price<=20)]
# Out:
#        country                                        description  \
# 5011        US  Truly stunning, the Lewis Estate Riesling from...
# 15196   France  The home vineyard of Madiran's star, Alain Bru...
# 76570       US  Spectacular is the word that comes to mind her...
# 101580      US  Superb fruit highlights this tight, sculpted S...
# 126242      US  With residual sugar at about 1.35%, this balan...
#
#                   designation  points  price          province  \
# 5011    Lewis Estate Vineyard      95   20.0        Washington
# 15196       Château Bouscassé      95   20.0  Southwest France
# 76570        Bacchus Vineyard      95   20.0        Washington
# 101580                    NaN      96   20.0        Washington
# 126242                    NaN      95   20.0        Washington
#
#                     region_1         region_2   taster_name  \
# 5011    Columbia Valley (WA)  Columbia Valley  Paul Gregutt
# 15196                Madiran              NaN    Roger Voss
# ...

# %% [markdown]
# ### Q4. Select all rows where `country` is either 'Italy' or 'France'.

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') | (wine_reviews.country == 'France')]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %% [markdown]
# ### Q5. Get the row with the highest `points` value using `.idxmax()`.

# %%
best_wine = wine_reviews.loc[wine_reviews.points.idxmax()]

# %% [markdown]
# ### Q6. Count how many reviews have a null `price`.

# %%
wine_reviews.price.isnull().sum()
# Out:
# 8996

# %% [markdown]
# ### Q7. Find the mean `points` and the median `price`.

# %%
wine_median=wine_reviews.points.median()
wine_mean=wine_reviews.points.mean()
print(wine_median , wine_mean)
# Out:
# 88.0 88.44713820775404

# %% [markdown]
# ### Q8. Get unique values in `country` and count them.

# %%
wine_reviews.country.value_counts()
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# ### Q9. Rename `points` to `rating` and `price` to `cost`.

# %%
wine_reviews.rename(columns={'points': 'rating' , 'price': 'cost'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  rating  cost  \
# 0                                 Vulkà Bianco      87   NaN
# ...

# %% [markdown]
# ### Q10. Sort the DataFrame by `cost` descending, then `rating` descending.

# %%
wine_reviews.sort_values(by=['price' , 'points' ], ascending=[False, False])
# Out:
#          country                                        description  \
# 80290     France  This ripe wine shows plenty of blackberry frui...
# 15840     France  The wine is a velvet glove in an iron fist. Th...
# 98380     France  A superb wine from a great year, this is power...
# 120391        US  The nose on this single-vineyard wine from a s...
# 65352     France  This extravagantly perfumed wine has great jui...
# ...          ...                                                ...
# 107767     Italy  A boxed wine, this blend of Pinot Noir and Mer...
# 121877    France  This is a yeasty wine, with the fruit less evi...
# 123461     Italy  There aren't that many organic Proseccos out t...
# 117025  Portugal  A curious sauerkraut perfume leads to a hard e...
# 123541     Italy  This Valpolicella blend opens with an aged, br...
#
#                 designation  points   price    province  \
# 80290                   NaN      88  3300.0    Bordeaux
# ...
